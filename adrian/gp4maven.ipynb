# %%
# %load_ext autoreload
# %autoreload 2
from caat import CAAT, DataCube, SN, SNCollection, GP, GP3D, SNModel
from caat.utils import WLE
import json
import matplotlib.pyplot as plt
import numpy as np
import logging
from sklearn.gaussian_process.kernels import Matern, RBF, WhiteKernel
import glob
import pandas as pd
from itertools import chain
from collections import defaultdict

logger = logging.getLogger()
logger.setLevel(logging.ERROR)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
caat = CAAT()

# %%
##################################################################
#
#
#       adding in data, only run if first time ever
#
#
##################################################################

# %%
# sn_names = ['SN2018avy', 'SN2019cad', 'SN2019cri', 'SN2019hgp', 'SN2019hty',
#        'SN2019tsf', 'SN2019vsi', 'SN2020adnx', 'SN2020bqj', 'SN2020sgf',
#        'SN2020urc', 'SN2020xpn', 'SN2021gno', 'SN2021hrj', 'SN2022hnt',
#        'SN2022oqm', 'SN2023gwl', 'SN2023psq', 'SN2024zsw', 'SN2025aot']

sn_names = ['SN2019tsf', 'SN2020adnx', 'SN2020urc', 'SN2021gno', 'SN2022hnt', 'SN2023gwl', 'SN2024zsw']

for i, name in enumerate(sn_names):
    try:
        sn = SN(name=name) # Instantiate SN class for single object
        print(name, sn.info) # The metadata for this object
    except:
        print(f"object {name} not in caat database...")
# Out:
# SN2019tsf {}
# SN2020adnx {'peak_mjd': 59226.31415931127, 'peak_mag': 17.792909142225035, 'peak_filt': 'g', 'searched': True, 'z': 0.021001, 'ra': 46.481375, 'dec': 41.608711}
# SN2020urc {'peak_mjd': 59144.85987639222, 'peak_mag': 18.52798968023504, 'peak_filt': 'g', 'searched': True, 'z': 0.026728, 'ra': 34.5461126, 'dec': 37.097234}
# SN2021gno {'peak_mjd': 59305.56318551056, 'peak_mag': 17.49515786162694, 'peak_filt': 'g', 'searched': True, 'z': 0.006211, 'ra': 183.042875, 'dec': 13.249181}
# SN2022hnt {'peak_mjd': 60633.64116896331, 'peak_mag': 18.55297303784181, 'peak_filt': 'r', 'searched': True, 'z': 0.0192, 'ra': 174.24897524285714, 'dec': 55.1639571}
# SN2023gwl {'peak_mjd': 60080.42424507897, 'peak_mag': 18.939745513031667, 'peak_filt': 'g', 'searched': True, 'z': 0.0346, 'ra': 198.8414944, 'dec': 1.9275673}
# SN2024zsw {'peak_mjd': 60633.54660111143, 'peak_mag': 18.551367178525062, 'peak_filt': 'r', 'searched': True, 'z': 0.032286, 'ra': 20.793617, 'dec': 19.570172}

# %%
# need to add in ztf data to caat 
# pull from mmmp/temp/gopreaux/*json files for each SN w/o data
# ztf2add = ['ZTF20adadlqm', 'ZTF23aaialcw', 'ZTF24abpdzvm'] done: 'ZTF20acgiglu

with open('/Users/pnr5sh/Documents/phd/mmmp/adrian/temp/gopreaux/ZTF20acgiglu_ztf_fp.json', 'r') as file:
    data = json.load(file)
    
with open('/Users/pnr5sh/Documents/phd/mmmp/adrian/temp/gopreaux/ZTF20acgiglu_info.json', 'r') as file:
    info = json.load(file)

new_sn = SN(
    name="SN2020urc",
    data=data,
    type="SESNe",
    subtype="SNIIb",
    info=info,
)

new_sn.plot_data()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[120], line 19
#       9     info = json.load(file)
#      11 new_sn = SN(
#      12     name="SN2020urc",
#      13     data=data,
#    (...)
#      16     info=info,
#      17 )
# ---> 19 new_sn.plot_data()
#
# File ~/Documents/phd/gopreaux/src/caat/SN.py:553, in SN.plot_data(self, filts_to_plot, shifted_data_exists, view_shifted_data, offset, plot_fluxes)
#     550         self.convert_all_mags_to_fluxes()
#     551     data_to_plot = self.data
# --> 553 Plot().plot_sn_data(
#     554     sn_class=self,
#     555     data_to_plot=data_to_plot,
#     556     filts_to_plot=filts_to_plot,
#     557     plot_fluxes=plot_fluxes,
#     558 )
#
# File ~/Documents/phd/gopreaux/src/caat/Plot.py:144, in Plot.plot_sn_data(self, sn_class, data_to_plot, filts_to_plot, plot_fluxes)
#     142 plt.title(sn_class.name)
# ...

# %%
new_sn.fit_for_max(filt="g", plot=True,offset=15)
print(new_sn.info)
# Out:
# {'ra': 34.5461126, 'dec': 37.097234, 'z': 0.026728, 'peak_mjd': 59144.85987639222, 'peak_mag': 18.52798968023504, 'peak_filt': 'g', 'searched': True}

# %%
# saving the max-fit and SN data to repo
new_sn.write_info_to_caat_file(force=True)
new_sn.write_json_data(dry_run=False)

# %%
# need to add in ztf data to caat 
# pull from mmmp/temp/gopreaux/*json files for each SN w/o data
# ztf2add = ['ZTF20adadlqm', 'ZTF23aaialcw', 'ZTF24abpdzvm'] done: 'ZTF20acgiglu

with open('/Users/pnr5sh/Documents/phd/mmmp/adrian/temp/gopreaux/ZTF20adadlqm_ztf_fp.json', 'r') as file:
    data = json.load(file)
    
with open('/Users/pnr5sh/Documents/phd/mmmp/adrian/temp/gopreaux/ZTF20adadlqm_info.json', 'r') as file:
    info = json.load(file)

new_sn = SN(
    name="SN2020adnx",
    data=data,
    type="SESNe",
    subtype="SNIIb",
    info=info,
)

new_sn.plot_data()

new_sn.fit_for_max(filt="g", plot=True, offset=15)
print(new_sn.info)
# Out:
# {'ra': 46.481375, 'dec': 41.608711, 'z': 0.021001, 'peak_mjd': 59226.31415931127, 'peak_mag': 17.792909142225035, 'peak_filt': 'g', 'searched': True}

# %%
# saving the max-fit and SN data to repo
new_sn.write_info_to_caat_file(force=True)
new_sn.write_json_data(dry_run=False)

# %%
# need to add in ztf data to caat 
# pull from mmmp/temp/gopreaux/*json files for each SN w/o data
# ztf2add = ['ZTF23aaialcw', 'ZTF24abpdzvm'] done: ZTF20acgiglu, ZTF20adadlqm

with open('/Users/pnr5sh/Documents/phd/mmmp/adrian/temp/gopreaux/ZTF23aaialcw_ztf_fp.json', 'r') as file:
    data = json.load(file)
    
with open('/Users/pnr5sh/Documents/phd/mmmp/adrian/temp/gopreaux/ZTF23aaialcw_info.json', 'r') as file:
    info = json.load(file)

new_sn = SN(
    name="SN2023gwl",
    data=data,
    type="SESNe",
    subtype="SNIIb",
    info=info,
)

new_sn.plot_data()

new_sn.fit_for_max(filt="g", plot=True, offset=15)
print(new_sn.info)
# Out:
# {'ra': 198.8414944, 'dec': 1.9275673, 'z': 0.0346, 'peak_mjd': 60080.42424507897, 'peak_mag': 18.939745513031667, 'peak_filt': 'g', 'searched': True}

# %%
# saving the max-fit and SN data to repo
new_sn.write_info_to_caat_file(force=True)
new_sn.write_json_data(dry_run=False)

# %%
# need to add in ztf data to caat 
# pull from mmmp/temp/gopreaux/*json files for each SN w/o data
# ztf2add = ['ZTF24abpdzvm'] done: ZTF20acgiglu, ZTF20adadlqm, ZTF23aaialcw

with open('/Users/pnr5sh/Documents/phd/mmmp/adrian/temp/gopreaux/ZTF24abpdzvm_ztf_fp.json', 'r') as file:
    data = json.load(file)
    
with open('/Users/pnr5sh/Documents/phd/mmmp/adrian/temp/gopreaux/ZTF24abpdzvm_info.json', 'r') as file:
    info = json.load(file)

new_sn = SN(
    name="SN2024zsw",
    data=data,
    type="SESNe",
    subtype="SNIIb",
    info=info,
)

new_sn.plot_data()

new_sn.fit_for_max(filt="r", plot=True, offset=20)
print(new_sn.info)
# Out:
# {'ra': 20.793617, 'dec': 19.570172, 'z': 0.032286, 'peak_mjd': 60633.54660111143, 'peak_mag': 18.551367178525062, 'peak_filt': 'r', 'searched': True}

# %%
# saving the max-fit and SN data to repo
new_sn.write_info_to_caat_file(force=True)
new_sn.write_json_data(dry_run=False)

# %%
#TODO: come back to this object later
# new_sn = SN(
#     name="SN2019tsf",
# )
# new_sn.plot_data(filts_to_plot=['g', 'r'])
# new_sn.fit_for_max(filt="r", plot=True)
# print(new_sn.info)

# %%
#adding in 22hnt ztf data to caat

with open('/Users/pnr5sh/Documents/phd/mmmp/adrian/temp/gopreaux/ZTF22aafrjnw_ztf_fp.json', 'r') as file:
    data = json.load(file)
    
with open('/Users/pnr5sh/Documents/phd/mmmp/adrian/temp/gopreaux/ZTF22aafrjnw_info.json', 'r') as file:
    info = json.load(file)

new_sn = SN(
    name="SN2022hnt",
    data=data,
    type="SESNe",
    subtype="SNIIb",
    info=info,
)

new_sn.plot_data()

new_sn.fit_for_max(filt="r", plot=True)
print(new_sn.info)
# Out:
# {'ra': 174.2489621, 'dec': 55.1639605, 'z': 0.0192, 'peak_mjd': 60633.64116896331, 'peak_mag': 18.55297303784181, 'peak_filt': 'r', 'searched': True}

# %%
# saving the max-fit and SN data to repo
new_sn.write_info_to_caat_file(force=True)
new_sn.write_json_data(dry_run=False)

# %%
# double checking the objects now appear in the caat

sn_names = ['SN2020adnx', 'SN2020urc', 'SN2021gno', 'SN2022hnt', 'SN2023gwl', 'SN2024zsw'] #'SN2019tsf'

for i, name in enumerate(sn_names):
    try:
        sn = SN(name=name) # Instantiate SN class for single object
        print(name, sn.info) # The metadata for this object
    except:
        print(f"object {name} not in caat database...")
# Out:
# SN2020adnx {'peak_mjd': 59226.31415931127, 'peak_mag': 17.792909142225035, 'peak_filt': 'g', 'searched': True, 'z': 0.021001, 'ra': 46.481375, 'dec': 41.608711}
# SN2020urc {'peak_mjd': 59144.85987639222, 'peak_mag': 18.52798968023504, 'peak_filt': 'g', 'searched': True, 'z': 0.026728, 'ra': 34.5461126, 'dec': 37.097234}
# SN2021gno {'peak_mjd': 59305.56318551056, 'peak_mag': 17.49515786162694, 'peak_filt': 'g', 'searched': True, 'z': 0.006211, 'ra': 183.042875, 'dec': 13.249181}
# SN2022hnt {'peak_mjd': 60633.64116896331, 'peak_mag': 18.55297303784181, 'peak_filt': 'r', 'searched': True, 'z': 0.0192, 'ra': 174.24897524285714, 'dec': 55.1639571}
# SN2023gwl {'peak_mjd': 60080.42424507897, 'peak_mag': 18.939745513031667, 'peak_filt': 'g', 'searched': True, 'z': 0.0346, 'ra': 198.8414944, 'dec': 1.9275673}
# SN2024zsw {'peak_mjd': 60633.54660111143, 'peak_mag': 18.551367178525062, 'peak_filt': 'r', 'searched': True, 'z': 0.032286, 'ra': 20.793617, 'dec': 19.570172}

# %%
#cube-ing it up

for i, name in enumerate(sn_names):
    sn = SN(name=name)
    cube = DataCube(sn=sn)

    cube.measure_flux_in_filter(plot=False,
                                save=True,
                                overwrite=True)

# %%
##################################################################
#
#
#                          doing GP fits
#
#
##################################################################

# %%
sn_names = ['SN2020adnx', 'SN2020urc', 'SN2021gno', 'SN2022hnt', 'SN2023gwl', 'SN2024zsw', 'SN2022qzr', 'SN2021pb', 'SN2020sbw', 'SN2020rsc', 'SN2020ikq', ]
#excluding 'SN2016gkg' b/c not enough data in g/r bands

myobjs = SNCollection(names=sn_names)

# %%
kernel = RBF([np.log(10.0), np.log10(500.0)], (2.5, 5.0)) #(0.1, 10.0)

# The normalization set provides photometry used to construct residuals, which are then fit
# sn_to_normalize = SNCollection(sntype="SESNe", snsubtype='SNIIb')
sn_to_normalize = myobjs

# filts = ['UVW2', 'UVM2', 'UVW1', 'U', 'B', 'g', 'c', 'V', 'r', 'o', 'i']
filts = ['g', 'r']
phasemin = -20
phasemax = 50
log_transform = 22
mangle_sed = True

gp = GP3D(
    myobjs, 
    kernel, 
    filts,
    phasemin, 
    phasemax,
    set_to_normalize=sn_to_normalize,
    log_transform=log_transform,
    mangle_sed=mangle_sed
)

# %%
kernel_parameters = gp.optimize_hyperparams(subtract_polynomial=True)

# Let's look at the kernel hyperparameters
optimized_kernel_hyperparams = np.asarray([np.median([k[i] for k in kernel_parameters]) for i in range(len(kernel_parameters[0]))])
print(np.exp(optimized_kernel_hyperparams))
# Out:
# [4.95871759 5.        ]

# %%
# %matplotlib inline
# sn_model = gp.predict(
#     plot=True,
#     subtract_polynomial=True,
#     fit_separately=True,
# )

sn_model = gp.run_gp_individually(
        plot=True,
        subtract_median=False,
        subtract_polynomial=True,
        interactive=False,
        run_diagnostics=False,
        save_individual_fits=True,
        overwrite=True,
    )

# %%
#############################################################################
#
#
#       generating many GP models from real photometry + initial model
#
#
#############################################################################

# %%
dp_models = glob.glob("../data/final_models/SN*_GP_model.fits")
for i,model in enumerate(dp_models):
    print(i,model)
# Out:
# 0 ../data/final_models/SN2021pb_GP_model.fits
# 1 ../data/final_models/SN2021gno_GP_model.fits
# 2 ../data/final_models/SN2022qzr_GP_model.fits
# 3 ../data/final_models/SN2023gwl_GP_model.fits
# 4 ../data/final_models/SN2020sbw_GP_model.fits
# 5 ../data/final_models/SN2020urc_GP_model.fits
# 6 ../data/final_models/SN2020rsc_GP_model.fits
# 7 ../data/final_models/SN2020adnx_GP_model.fits
# 8 ../data/final_models/SN2020ikq_GP_model.fits
# 9 ../data/final_models/SN2024zsw_GP_model.fits
# 10 ../data/final_models/SN2022hnt_GP_model.fits

# %%
"""
# This function uses an older version of SNModel.fit_photometry
"""

for i,sn in enumerate(sn_names): 
    model = SNModel(
        surface=f"{sn}_GP_model.fits",
    )

    data = pd.read_csv(f'../data/SESNe/SNIIb/{sn}/{sn}_datacube_mangled.csv')
    datadf = data.loc[(data['Nondetection']==False)&((data['Filter']=='g')|(data['Filter']=='r'))&(data['Phase']>model.min_phase)&(data['Phase']<model.max_phase),
                    ['Phase', 'Filter', 'ShiftedMag', 'Magerr']]
    
    #changing df column names to match expected names of fit_photometry function
    datadf.rename(columns={'Magerr': 'MagErr'}, inplace=True)
    # datadf.rename(columns={'ShiftedMag':'Mag'}, inplace=True)

    if sn in ['SN2022qzr', 'SN2021pb', 'SN2020sbw', 'SN2020rsc', 'SN2020ikq']: #some objs have inverse mags, so flipping them back
        datadf['Mag'] = -1*datadf['ShiftedMag']
    else:
        datadf.rename(columns={'ShiftedMag':'Mag'}, inplace=True)

    # print(model.min_phase)
    model.fit_photometry_v0(
        photometry=datadf,
        phase_min=model.min_phase,
        phase_max=model.max_phase,
        show=True,
        nsamples=30, 
        save4adrian=False,
        savedir = 'nsample_GP_models_v2/',
    )
    # fits are actually good, there is just a conversion error/bug when plotting here

# %%
# trying out the new version of SNModel.fit_photometry

for i,sn in enumerate(sn_names):
    model = SNModel(
        surface=f"{sn}_GP_model.fits",
    )

    model.fit_photometry(
        sn_to_fit=model.sn,
        filters_to_fit=['g', 'r'],
        phase_min=model.min_phase,
        phase_max=model.max_phase,
        show=True,
        nsamples=30, 
        # save_individ_gps=False,
        # savedir = 'nsample_GP_models_v3/',
    )

# %%
################################################################
#
#
#            using GP models to make fake photometry
#
#
################################################################

# %%
def samples2dict(filepath: str) -> dict:
    """
    takes text file with lines in format SN,sample and
    converts into dictionary of format {SN:[sample]}
    """
    result = defaultdict(list)
    with open(filepath, "r") as f:
        for line in f:
            if line.startswith("#"):
                continue
            else:
                sn, sample = line.strip().split(",")
                result[sn].append(int(sample))
    return dict(result)

# %%
import re
def get_sn_name_from_file(text: str) -> str:
    """Remove all occurrences of '_sampleX_fake_LC.csv' from a string."""
    return re.sub(r'_sample\d+\_fake_LC.csv', '', text)

# %%
# No need to rerun --- #adding in avg error from real LC to fake LC ---

fake_lc_files = glob.glob('fake_LCs/*.csv')
fake_lc_files = sorted(fake_lc_files)

#randomly drawing photometry points from the good fits
for i,file in enumerate(fake_lc_files):
    #isolating name of SN from file
    sn = get_sn_name_from_file(file[9:])

    #reading in actual LC data to get errors from
    data = pd.read_csv(f'../data/SESNe/SNIIb/{sn}/{sn}_datacube_mangled.csv')
    magerrs = data.loc[(data['Nondetection']==False)&((data['Filter']=='g')|(data['Filter']=='r'))&(data['Phase']>model.min_phase)&(data['Phase']<model.max_phase),
                    ['Magerr']]
    avg_err = np.mean(magerrs)
    avg_err_g = np.mean(magerrs.loc[data['Filter']=='g'])
    avg_err_r = np.mean(magerrs.loc[data['Filter']=='r'])

    # #reading in full GP model and interpolated LC data
    # fake_data = pd.read_csv(file)                                 # LC data
    # # fake_data['fluxerr'] = np.ones(len(fake_data))*avg_err
    # fake_data['fluxerr'] = np.ones(len(fake_data))
    # fake_data.loc[fake_data['filt']=='g', 'fluxerr'] = avg_err_g
    # fake_data.loc[fake_data['filt']=='r', 'fluxerr'] = avg_err_r
    # fake_data.to_csv(file, index=False)

    #saving the avg err for each object as txt file
    with open('avg_lc_err.txt','a') as file:
        file.write(f"{sn},{avg_err_g},{avg_err_r}" + '\n')

# %%
dictt = samples2dict('good_searched_files.txt')
smthn = np.array([np.array([x,len(dictt[x])]) for x in dictt.keys()])
plt.bar(range(len(smthn)), smthn[:,1].astype(int))
plt.xticks(labels=smthn[:,0], ticks=range(len(smthn)), rotation=45);

# %%
# plotting the interpolated observations from the GP fits 

# plt.rcParams['axes.titlesize'] = 25    # Title size
# plt.rcParams['axes.labelsize'] = 25    # X and Y label size
plt.rcParams['xtick.labelsize'] = 24   # X-axis tick label size
plt.rcParams['ytick.labelsize'] = 24   # Y-axis tick label size
plt.rcParams['legend.fontsize'] = 22   # Legend font size

fake_lc_files = glob.glob('fake_LCs/rand_added/*.csv')
fake_lc_files = sorted(fake_lc_files)

for i,file in enumerate(fake_lc_files):
    #isolating name of SN from file
    sn = get_sn_name_from_file(file[20:])

    #reading in the real data
    data = pd.read_csv(f'../data/SESNe/SNIIb/{sn}/{sn}_datacube_mangled.csv')
    datadf = data.loc[(data['Nondetection']==False)&((data['Filter']=='g')|(data['Filter']=='r'))&(data['Phase']>-20)&(data['Phase']<50),
                    ['Phase', 'Filter', 'ShiftedMag', 'Magerr']]
    
    #changing df column names to match expected names of fit_photometry function
    datadf.rename(columns={'Magerr': 'MagErr'}, inplace=True)
    # datadf.rename(columns={'ShiftedMag':'Mag'}, inplace=True)

    if sn in ['SN2022qzr', 'SN2021pb', 'SN2020sbw', 'SN2020rsc', 'SN2020ikq']: #some objs have inverse mags, so flipping them back
        datadf['Mag'] = -1*datadf['ShiftedMag']
    else:
        datadf.rename(columns={'ShiftedMag':'Mag'}, inplace=True)


    #reading in full GP model and interpolated LC data
    gp_data = pd.read_csv(f'nsample_GP_models/{sn}_GP_model.csv') # full model
    fake_data = pd.read_csv(file)                                 # LC data

    sample = fake_data['sample'].unique()[0]
    g_inds = (gp_data['filt']=='g')
    r_inds = (gp_data['filt']=='r')

    plt.figure(figsize=(11,6))
    # plt.scatter(fake_data.loc[fake_data['filt']=='g','time'], 
    #             -2.5*np.log10(fake_data.loc[fake_data['filt']=='g','flux']+5)-17)
    # plt.gca().invert_yaxis()

    #real photometry
    plt.errorbar(datadf.loc[datadf['Filter']=='g', 'Phase'], datadf.loc[datadf['Filter']=='g', 'Mag'], datadf.loc[datadf['Filter']=='g', 'MagErr'], 
                ls='', marker='.', color='teal', alpha=0.6, markersize=15,zorder=0,label='ZTF-g')
    plt.errorbar(datadf.loc[datadf['Filter']=='r', 'Phase'], datadf.loc[datadf['Filter']=='r', 'Mag'], datadf.loc[datadf['Filter']=='r', 'MagErr'], 
                ls='', marker='.', color='tomato', alpha=0.6,  markersize=15,zorder=0,label='ZTF-r')
    
    #GP model
    plt.plot(gp_data.loc[g_inds&(gp_data['sample']==sample),'time'], gp_data.loc[g_inds&(gp_data['sample']==sample),'flux'], 
            color='cyan', zorder=1, alpha=0.6,label='GP model - g',linewidth=4)
    plt.plot(gp_data.loc[r_inds&(gp_data['sample']==sample),'time'], gp_data.loc[r_inds&(gp_data['sample']==sample),'flux'], 
            color='orange', zorder=1, alpha=0.6, label='GP model - r',linewidth=4)

    #fake photometry
    plt.errorbar(fake_data.loc[fake_data['filt']=='g','time'], 
                fake_data.loc[fake_data['filt']=='g','flux_rand'],
                yerr=fake_data.loc[fake_data['filt']=='g','flux_err'],
                markerfacecolor='cyan', markeredgecolor='k', ecolor='cyan', ls='',ms=28,marker='.',label='GP - g')
    plt.errorbar(fake_data.loc[fake_data['filt']=='r', 'time'], 
                fake_data.loc[fake_data['filt']=='r', 'flux_rand'],
                yerr=fake_data.loc[fake_data['filt']=='r','flux_err'], 
                markerfacecolor='orange', markeredgecolor='k', ecolor='orange', ls='',ms=28,marker='.',label='GP - r')
    
    # plt.title(f"{sn}-sample {sample}")
    # plt.annotate(f"{sn}", xy=(0.645,0.91), xycoords='axes fraction', fontsize=28, color='dimgray')
    # plt.annotate(f"sample {sample}", xy=(0.745,0.835), xycoords='axes fraction', fontsize=25, color='gray')
    plt.xlabel('Phase [days]', fontsize=30)
    plt.ylabel('Relative Magnitude', fontsize=30)
    plt.xticks([-20,0,20,40])
    plt.tick_params(axis='both', direction='in')
    plt.legend(bbox_to_anchor=(0.98, 0.57), frameon=False)
    plt.tight_layout()
    plt.savefig(f'fake_LCs/rand_added/lc_overlays/{sn}_sample_{sample}.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
# plotting the interpolated observations from the GP fits 

# plt.rcParams['axes.titlesize'] = 25    # Title size
# plt.rcParams['axes.labelsize'] = 25    # X and Y label size
plt.rcParams['xtick.labelsize'] = 24   # X-axis tick label size
plt.rcParams['ytick.labelsize'] = 24   # Y-axis tick label size
plt.rcParams['legend.fontsize'] = 22   # Legend font size

fake_lc_files = glob.glob('fake_LCs/rand_added/*.csv')
fake_lc_files = sorted(fake_lc_files)

for i,file in enumerate(fake_lc_files):
    if i in [0,4,23]:
        #isolating name of SN from file
        sn = get_sn_name_from_file(file[20:])

        #reading in the real data
        data = pd.read_csv(f'../data/SESNe/SNIIb/{sn}/{sn}_datacube_mangled.csv')
        datadf = data.loc[(data['Nondetection']==False)&((data['Filter']=='g')|(data['Filter']=='r'))&(data['Phase']>-20)&(data['Phase']<50),
                        ['Phase', 'Filter', 'ShiftedMag', 'Magerr']]
        
        #changing df column names to match expected names of fit_photometry function
        datadf.rename(columns={'Magerr': 'MagErr'}, inplace=True)
        # datadf.rename(columns={'ShiftedMag':'Mag'}, inplace=True)

        if sn in ['SN2022qzr', 'SN2021pb', 'SN2020sbw', 'SN2020rsc', 'SN2020ikq']: #some objs have inverse mags, so flipping them back
            datadf['Mag'] = -1*datadf['ShiftedMag']
        else:
            datadf.rename(columns={'ShiftedMag':'Mag'}, inplace=True)


        #reading in full GP model and interpolated LC data
        gp_data = pd.read_csv(f'nsample_GP_models/{sn}_GP_model.csv') # full model
        fake_data = pd.read_csv(file)                                 # LC data

        sample = fake_data['sample'].unique()[0]
        g_inds = (gp_data['filt']=='g')
        r_inds = (gp_data['filt']=='r')

        plt.figure(figsize=(11,6))
        # plt.scatter(fake_data.loc[fake_data['filt']=='g','time'], 
        #             -2.5*np.log10(fake_data.loc[fake_data['filt']=='g','flux']+5)-17)
        # plt.gca().invert_yaxis()

        #real photometry
        plt.errorbar(datadf.loc[datadf['Filter']=='g', 'Phase'], datadf.loc[datadf['Filter']=='g', 'Mag'], datadf.loc[datadf['Filter']=='g', 'MagErr'], 
                    ls='', marker='.', color='teal', alpha=0.6, markersize=15,zorder=0,label='ZTF-g')
        plt.errorbar(datadf.loc[datadf['Filter']=='r', 'Phase'], datadf.loc[datadf['Filter']=='r', 'Mag'], datadf.loc[datadf['Filter']=='r', 'MagErr'], 
                    ls='', marker='.', color='tomato', alpha=0.6,  markersize=15,zorder=0,label='ZTF-r')
        
        #GP model
        plt.plot(gp_data.loc[g_inds&(gp_data['sample']==sample),'time'], gp_data.loc[g_inds&(gp_data['sample']==sample),'flux'], 
                color='cyan', zorder=1, alpha=0.6,label='GP model: g',linewidth=4)
        plt.plot(gp_data.loc[r_inds&(gp_data['sample']==sample),'time'], gp_data.loc[r_inds&(gp_data['sample']==sample),'flux'], 
                color='orange', zorder=1, alpha=0.6, label='GP model: r',linewidth=4)

        #fake photometry
        plt.errorbar(fake_data.loc[fake_data['filt']=='g','time'], 
                    fake_data.loc[fake_data['filt']=='g','flux_rand'],
                    yerr=fake_data.loc[fake_data['filt']=='g','flux_err'],
                    markerfacecolor='cyan', markeredgecolor='k', ecolor='cyan', ls='',ms=28,marker='.',label='GP-g')
        plt.errorbar(fake_data.loc[fake_data['filt']=='r', 'time'], 
                    fake_data.loc[fake_data['filt']=='r', 'flux_rand'],
                    yerr=fake_data.loc[fake_data['filt']=='r','flux_err'], 
                    markerfacecolor='orange', markeredgecolor='k', ecolor='orange', ls='',ms=28,marker='.',label='GP-r')
        
        # plt.title(f"{sn}-sample {sample}")
        if i==23:
            plt.annotate(f"{sn}", xy=(0.645,0.91), xycoords='axes fraction', fontsize=28, color='dimgray')
            plt.annotate(f"sample {sample}", xy=(0.745,0.835), xycoords='axes fraction', fontsize=25, color='gray')
        elif i==4:
            plt.annotate(f"{sn}", xy=(0.665,0.91), xycoords='axes fraction', fontsize=28, color='dimgray')
            plt.annotate(f"sample {sample}", xy=(0.74,0.835), xycoords='axes fraction', fontsize=25, color='gray')
        elif i==0:
            plt.annotate(f"{sn}", xy=(0.615,0.91), xycoords='axes fraction', fontsize=28, color='dimgray')
            plt.annotate(f"sample {sample}", xy=(0.715,0.835), xycoords='axes fraction', fontsize=25, color='gray')
        
        plt.xlabel('Phase [days]', fontsize=30)
        plt.ylabel('Relative Magnitude', fontsize=30)
        plt.xticks([-20,0,20,40])
        plt.tick_params(axis='both', direction='in')

        handles, labels = plt.gca().get_legend_handles_labels()
        desired_order = ['ZTF-g', 'ZTF-r', 'GP model: g', 'GP model: r', 'GP-g', 'GP-r']
        order = [labels.index(l) for l in desired_order]
        plt.legend([handles[i] for i in order], [labels[i] for i in order],bbox_to_anchor=(0.98, 0.57), frameon=False)
        
        plt.tight_layout()
        plt.savefig(f'fake_LCs/rand_added/lc_overlays/{sn}_sample_{sample}.png', dpi=300, bbox_inches='tight')
        plt.show()

# %%
### remaking the above plot, now below, and with the full GP model and not 1 realization

# %%
# plt.rcParams['axes.titlesize'] = 25    # Title size
# plt.rcParams['axes.labelsize'] = 25    # X and Y label size
plt.rcParams['xtick.labelsize'] = 24   # X-axis tick label size
plt.rcParams['ytick.labelsize'] = 24   # Y-axis tick label size
plt.rcParams['legend.fontsize'] = 22   # Legend font size

fake_lc_files = glob.glob('fake_LCs/rand_added/*.csv')
fake_lc_files = sorted(fake_lc_files)

for i,file in enumerate(fake_lc_files):
    if i in [0,4,23]:
        #isolating name of SN from file
        sn = get_sn_name_from_file(file[20:])

        #reading in the real data
        data = pd.read_csv(f'../data/SESNe/SNIIb/{sn}/{sn}_datacube_mangled.csv')
        datadf = data.loc[(data['Nondetection']==False)&((data['Filter']=='g')|(data['Filter']=='r'))&(data['Phase']>-20)&(data['Phase']<50),
                        ['Phase', 'Filter', 'ShiftedMag', 'Magerr']]
        
        #changing df column names to match expected names of fit_photometry function
        datadf.rename(columns={'Magerr': 'MagErr'}, inplace=True)
        # datadf.rename(columns={'ShiftedMag':'Mag'}, inplace=True)

        if sn in ['SN2022qzr', 'SN2021pb', 'SN2020sbw', 'SN2020rsc', 'SN2020ikq']: #some objs have inverse mags, so flipping them back
            datadf['Mag'] = -1*datadf['ShiftedMag']
        else:
            datadf.rename(columns={'ShiftedMag':'Mag'}, inplace=True)

        #reading in OG GP model
        model = SNModel(
            surface=f"{sn}_GP_model.fits",
        )

        #reading in full GP model and interpolated LC data
        # gp_data = pd.read_csv(f'nsample_GP_models/{sn}_GP_model.csv') # full model
        fake_data = pd.read_csv(file)                                 # LC data

        sample = fake_data['sample'].unique()[0]
        g_inds = (gp_data['filt']=='g')
        r_inds = (gp_data['filt']=='r')

        plt.figure(figsize=(11,6))

        #real photometry
        plt.errorbar(datadf.loc[datadf['Filter']=='g', 'Phase'], datadf.loc[datadf['Filter']=='g', 'Mag'], datadf.loc[datadf['Filter']=='g', 'MagErr'], 
                    ls='', marker='.', color='teal', alpha=0.6, markersize=15,zorder=0,label='ZTF-g')
        plt.errorbar(datadf.loc[datadf['Filter']=='r', 'Phase'], datadf.loc[datadf['Filter']=='r', 'Mag'], datadf.loc[datadf['Filter']=='r', 'MagErr'], 
                    ls='', marker='.', color='tomato', alpha=0.6,  markersize=15,zorder=0,label='ZTF-r')
        
        #GP model
        if i!=4:
            model.predict_lightcurve(-10, 48, 4830)
        else:
            model.predict_lightcurve(-1, 45, 4830)
        # plt.plot(gp_data.loc[g_inds&(gp_data['sample']==sample),'time'], gp_data.loc[g_inds&(gp_data['sample']==sample),'flux'], 
        #         color='cyan', zorder=1, alpha=0.6,label='GP model: g',linewidth=4)
        # plt.plot(gp_data.loc[r_inds&(gp_data['sample']==sample),'time'], gp_data.loc[r_inds&(gp_data['sample']==sample),'flux'], 
        #         color='orange', zorder=1, alpha=0.6, label='GP model: r',linewidth=4)

        #fake photometry
        plt.errorbar(fake_data.loc[fake_data['filt']=='g','time'], 
                    fake_data.loc[fake_data['filt']=='g','flux_rand'],
                    yerr=fake_data.loc[fake_data['filt']=='g','flux_err'],
                    markerfacecolor='cyan', markeredgecolor='k', ecolor='cyan', ls='',ms=28,marker='.',label='GP-g')
        plt.errorbar(fake_data.loc[fake_data['filt']=='r', 'time'], 
                    fake_data.loc[fake_data['filt']=='r', 'flux_rand'],
                    yerr=fake_data.loc[fake_data['filt']=='r','flux_err'], 
                    markerfacecolor='orange', markeredgecolor='k', ecolor='orange', ls='',ms=28,marker='.',label='GP-r')
        
        # plt.title(f"{sn}-sample {sample}")
        if i==23:
            plt.annotate(f"{sn}", xy=(0.645,0.91), xycoords='axes fraction', fontsize=28, color='dimgray')
            # plt.annotate(f"sample {sample}", xy=(0.745,0.835), xycoords='axes fraction', fontsize=25, color='gray')
        elif i==4:
            plt.annotate(f"{sn}", xy=(0.665,0.91), xycoords='axes fraction', fontsize=28, color='dimgray')
            # plt.annotate(f"sample {sample}", xy=(0.74,0.835), xycoords='axes fraction', fontsize=25, color='gray')
        elif i==0:
            plt.annotate(f"{sn}", xy=(0.615,0.91), xycoords='axes fraction', fontsize=28, color='dimgray')
            # plt.annotate(f"sample {sample}", xy=(0.715,0.835), xycoords='axes fraction', fontsize=25, color='gray')
        
        plt.xlabel('Phase [days]', fontsize=30)
        plt.ylabel('Relative Magnitude', fontsize=30)
        plt.xticks([-20,0,20,40])
        plt.tick_params(axis='both', direction='in')

        handles, labels = plt.gca().get_legend_handles_labels()
        # desired_order = ['ZTF-g', 'ZTF-r',  'GP-g', 'GP-r'] #'GP model: g', 'GP model: r',
        # order = [labels.index(l) for l in desired_order]
        # plt.legend([handles[i] for i in order], [labels[i] for i in order],bbox_to_anchor=(0.98, 0.57), frameon=False)
        
        plt.tight_layout()
        # plt.savefig(f'fake_LCs/rand_added/lc_overlays/{sn}_sample_{sample}.png', dpi=300, bbox_inches='tight')
        plt.show()

# %%
##########################################################
#
#
#   converting from gopreaux space to "real" data space
#
#
##########################################################

# %%
# plotting the interpolated observations from the GP fits 

fake_lc_files = glob.glob('fake_LCs/rand_added/*.csv')
fake_lc_files = sorted(fake_lc_files)

fnames_for_maven = []
for i,file in enumerate(fake_lc_files):
    # isolating name of SN from file
    sn = get_sn_name_from_file(file[20:])

    # reading in peak mjd, mag, filt 
    real_sn = SN(name=sn).info
    peak_time, peak_mag, peak_filt = real_sn['peak_mjd'], real_sn['peak_mag'], real_sn['peak_filt']

    # reading in interpolated LC data
    fake_data = pd.read_csv(file)

    sample = fake_data['sample'].unique()[0]
    g_inds = (fake_data['filt']=='g')
    r_inds = (fake_data['filt']=='r')

    # creating random time and mag shifts
    t_rand = np.random.uniform(-1000, 1000, 1)[0]
    m_rand = np.random.normal(0, 0.5, 1)[0]
    merr_rad = np.random.uniform(-0.025, 0.025, len(fake_data['flux_err']))

    #shift LC back to peak_mjd, peak_mag and then add t/m_rand offsets
    maven_df = fake_data[['time','filt','sample','flux_rand','flux_err']]
    maven_df['mjd'] = maven_df['time']+peak_time+t_rand

    offset = peak_mag - maven_df['flux_rand'].max()
    maven_df['mag'] = ((maven_df['flux_rand'] + offset + m_rand)*-1)+2*peak_mag #flips light curve to match magnitude-scaling

    maven_df['magerr'] = maven_df['flux_err'] + merr_rad

    #rename stuff for maven
        #maven has format: time,mag,magerr,band
        #where band is g,R
    maven_df.loc[maven_df['filt']=='r', 'filt'] = 'R'
    # maven_df['magerr'] = maven_df['flux_err']
    maven_df['band'] = maven_df['filt']

    #creating fake ztf name to save the files under
        #ZTFXXabcsYYx where XXabc is the actual name of the SN minus preceding ”20”
        # sYY is the sample number a
        # put however many trailing x’s to match the string length (7 characters after XX, or 12 total)
    sample = maven_df['sample'].unique()[0]
    sn_short = sn[4:]
    ztf_name = f'ZTF{sn_short}s{sample:02d}'
    if len(ztf_name) < 12:
        ztf_name += 'x' * (12 - len(ztf_name))
    
    #save df's 
    maven_df_final = maven_df[['mjd','mag','magerr','band']]
    maven_df_final = maven_df_final.rename(columns={"mjd":"time"})
    maven_df_final = maven_df_final.sort_values(by=["time"])
    maven_df_final.to_csv(f'fake_LCs/maven_ready/{ztf_name}_0.csv', index=False)
    fnames_for_maven.append(f'{ztf_name}_0.csv')

    plt.figure()
    plt.errorbar(maven_df_final.loc[maven_df_final['band']=='g', 'time'],
                 maven_df_final.loc[maven_df_final['band']=='g', 'mag'],
                 yerr=maven_df_final.loc[maven_df_final['band']=='g', 'magerr'],
                 color='cyan', ls='', marker='.')
    plt.errorbar(maven_df_final.loc[maven_df_final['band']=='R', 'time'],
                 maven_df_final.loc[maven_df_final['band']=='R', 'mag'],
                 yerr=maven_df_final.loc[maven_df_final['band']=='R', 'magerr'],
                 color='orange', ls='', marker='.')
    plt.gca().invert_yaxis()

# %%
# fnames_for_maven

with open("./fake_LCs/maven_ready/fnames4maven.txt", "w") as f:
    f.write("\n".join(fnames_for_maven))

# %%
# checking randomness
import matplotlib.ticker as ticker

# fake_lc_files = glob.glob('fake_LCs/rand_added/*.csv')
# fake_lc_files = sorted(fake_lc_files)

for i,sn in enumerate(sn_names):
    # reading in fake LC files for particular object
    fake_lc_files = glob.glob(f'fake_LCs/maven_ready/ZTF{sn[4:]}*.csv')
    fake_lc_files = sorted(fake_lc_files)

    # reading in peak mjd, mag, filt 
    real_sn = SN(name=sn).info
    peak_time, peak_mag, peak_filt = real_sn['peak_mjd'], real_sn['peak_mag'], real_sn['peak_filt']

    # find the closest obs in GP LC to peak of og LC
    peak_times_g, peak_mags_g = [],[]
    peak_times_r, peak_mags_r = [],[]
    for i,file in enumerate(fake_lc_files):
        lc_df = pd.read_csv(file)
        g_df = lc_df.loc[lc_df['band']=='g']
        r_df = lc_df.loc[lc_df['band']=='R']

        peak_g = g_df.loc[g_df['mag'].idxmin(), ['time', 'mag']]
        peak_times_g.append(peak_g['time'])
        peak_mags_g.append(peak_g['mag'])

        peak_r = r_df.loc[r_df['mag'].idxmin(), ['time', 'mag']]
        peak_times_r.append(peak_r['time'])
        peak_mags_r.append(peak_r['mag'])
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8,4))
    #g bands
    ax1.hist(peak_times_g, bins=len(peak_times_g), histtype='step', color='limegreen', linewidth=3)
    ax1.hist(peak_times_r, bins=len(peak_times_r), histtype='step', color='hotpink', linewidth=3, linestyle='dashed')
    ax1.axvline(peak_time, color='darkgray', zorder=0, ls='-', linewidth=3)
    ax1.set_title('peak time spread')
    ax1.yaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    ax2.hist(peak_mags_g, bins=len(peak_mags_g), histtype='stepfilled',color='limegreen', linewidth=3,alpha=0.5)
    ax2.hist(peak_mags_r, bins=len(peak_mags_r), histtype='step',color='hotpink', linewidth=3,linestyle='-')
    ax2.axvline(peak_mag, color='darkgray', zorder=0, ls='-', linewidth=3)
    ax2.set_title('peak mag spread')
    ax2.yaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    plt.suptitle(f'{sn}--{len(fake_lc_files)} copies')
    plt.savefig(f'./temp_plots/{sn}_randomness_spread_checks.png', dpi=200)
    plt.show()
